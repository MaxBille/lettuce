# %%
# IDEE
# - lese die punktuellen Zeitreihen von Druck und/oder Geschwindigkeit für HWBB, FWBB und "Keil" mal ein und mache eine FFT, um die zeitliche Oszillation darstellen zu können.
# -? bei welchen Sims habe ich die Zeitreihen oder welche möchte ich dafür mal laufen lassen?
# - da dabei ja vermutlich der größte Peak bei frequenz = 2 Zeitschrittweite ist (?) sollte dieser ganz rechts sein, oder? bzw. da wo ich nunmal abschneide. 
# a) anschauen
# b) Frequenzbereich abschneiden bei Zeitschrittweite...? oderso
