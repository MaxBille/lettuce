# %%
import lettuce as lt
import matplotlib.pyplot as plt

import warnings
import numpy as np
from lettuce.unit import UnitConversion
from lettuce.util import append_axes
from lettuce.boundary import EquilibriumBoundaryPU, BounceBackBoundary, EquilibriumOutletP, AntiBounceBackOutlet

import torch
import time

# %%
### Parameter
re = 100
n_steps = 400
ny = 5 #ny=2*nx
u_init = 1 #1= kein Geschwindigkeit, 2=poiseuille-artig
perturb_init = False # leichte Asymmetrie in Anfangs-Geschwindigkeitsverteilung -> Amplitude kann unten gewählt werden
u_in_parabel = True # True=parabel_in, False=constant_in
bb_wall = False # True= bounce-back-walls, False= periodic RB-walls
cylinder = True # True = cylinder obstacle, False = no obstascle
vtk_out = False # True = vtk-output, False = no vtk-output
vtk_interval=50
drag_out = True

# %%
### Cylinder2D: modifizierte obstacle.py Klasse, zur Simulation eines umströmten Zylinders

class Cylinder2D:

    def __init__(self, shape, reynolds_number, mach_number, lattice, domain_length_x, char_length=1, char_velocity=1, boundary=None):
        if len(shape) != lattice.D:
            raise ValueError(f"{lattice.D}-dimensional lattice requires {lattice.D}-dimensional `shape`")
        self.shape = shape
        char_length_lu = shape[0] / domain_length_x * char_length
        self.units = UnitConversion(
            lattice,
            reynolds_number=reynolds_number, mach_number=mach_number,
            characteristic_length_lu=char_length_lu, characteristic_length_pu=char_length,
            characteristic_velocity_pu=char_velocity
        )
        self._mask = np.zeros(shape=self.shape, dtype=bool) #deprecation warning: "np.bool" ist ein alter alias für das buildin "bool"
        self._boundary = boundary

    @property
    def mask(self):
        return self._mask

    @mask.setter
    def mask(self, m):
        assert isinstance(m, np.ndarray) and m.shape == self.shape
        self._mask = m.astype(bool) #deprecation warning: "np.bool" ist ein alter alias für das buildin "bool"

    def initial_solution(self, x):
        p = np.zeros_like(x[0], dtype=float)[None, ...]
        u_char = self.units.characteristic_velocity_pu * self._unit_vector()
        u_char = append_axes(u_char, self.units.lattice.D) # u_char ist in PU (!) -> 1.0
        u = (1 - self.mask) * u_char
        #print("u erste aus initial: ", u)
        
### Wähle initiale Geschwindigkeitsverteilung:
        #u_init = 0 # uniform ux=1.0
        
        if u_init == 1: # no velocity
            u = u * 0
        elif u_init ==2: # uniform parabolic (a bit like poiseuille-flow)
            ### initiale Geschwindigkeitsverteilung parabelförmig
            u = (1 - self.mask) * u_char
            ny = self.shape[1] #Gitterpunktzahl in y-Richtung           
            u1=np.zeros(ny)
            parabel_breite = ny-2
            y_werte = np.arange(0, parabel_breite) + 0.5
            u1[1:-1] = - self.units.characteristic_velocity_pu * y_werte * (y_werte - (parabel_breite)) * 1/(parabel_breite/2)**2
            print("u1 aus initial: ", u1)
            u=np.einsum('k,ijk->ijk',u1,u)
            print("u aus initial: ", u)

### Störe Initialverteilung für Asymmetrie
        if perturb_init:
            # überlagere Sinus-Störung in ux über die zweite Spalte
            ny = x[1].shape[1]
            if u.max() < 0.5*self.units.characteristic_velocity_pu:
                u[0][1] += np.sin(np.arange(0, ny) / ny * 2 * np.pi) * self.units.characteristic_velocity_pu * 1.0 #0.3
            else:
                u[0][1] *= 1 + np.sin(np.arange(0, ny) / ny * 2 * np.pi) * self.units.characteristic_velocity_pu * 0.3
            plt.plot(u[0][1])
        return p, u

    @property
    def grid(self):
        # linspace erlaubt endpoint=True im Gegensatz zu Arange "np.linspace(0,n,n)" war vorher "np.arange(n)"
        xyz = tuple(self.units.convert_length_to_pu(np.linspace(0,n,n)) for n in self.shape)
        return np.meshgrid(*xyz, indexing='ij')

    @property
    def boundaries(self):
        x = self.grid[0]
        
        # INLET mask
        inmask = np.zeros(self.grid[0].shape, dtype=bool)
        inmask[0, 1:-1] = True  # bzw. inmask [0,:] ABER DANN überlagern sich die Boundaries in den Ecken, bzw. auf jeden Ecke überlagern sich die Ränder mit den Wänden

### BB oder periodic RB auf oberem und unterem Rand    
        # BounceBack auf der oberen und unteren Wand:
        if bb_wall == True:
            self.mask[:, [0, -1]] = True

        if self._boundary is None: #falls _boundary nicht außerhalb der Klasse belegt wurde
            inlet_boundary = EquilibriumBoundaryPU(
                # np.abs(x) < 1e-6, # ursprüngliche Implementierung sucht hierrüber den Rand
                inmask, # definiert Einlass
                self.units.lattice, self.units,
                self.units.characteristic_velocity_pu * self._unit_vector()
            )
        else:
            inlet_boundary = self._boundary
        return [
            inlet_boundary,
            # AntiBounceBackOutlet(self.units.lattice, self._unit_vector().tolist()), #crasht, sobald der erste Wirbel den Auslass trifft
            EquilibriumOutletP(self.units.lattice, self._unit_vector().tolist()),  # wird von PyCharm als "unknown reference" markiert? -> LSG: stand oben im Import nicht drin (!)
            BounceBackBoundary(self.mask, self.units.lattice) #BounceBack definiert über self.mask, u.a. für das obstacle selbst (!)
        ]

    def _unit_vector(self, i=0):
        return np.eye(self.units.lattice.D)[i]

# %%
### Modifizierte EquilibrimuBoundaryPU aus boundary.py, welche die Möglichkeit eines parabelförmigen
### Geschwindigkeitsprofils am Einlass erlaubt.

class EquilibriumBoundaryPU:
    """Sets distributions on this boundary to equilibrium with predefined velocity and pressure.
    Note that this behavior is generally not compatible with the Navier-Stokes equations.
    This boundary condition should only be used if no better options are available.
    """

    def __init__(self, mask, lattice, units, velocity, pressure=0):
        self.mask = lattice.convert_to_tensor(mask)
        self.lattice = lattice
        self.units = units
        self.velocity = lattice.convert_to_tensor(velocity)
        self.pressure = lattice.convert_to_tensor(pressure)

    def __call__(self, f):
        rho = self.units.convert_pressure_pu_to_density_lu(self.pressure)
        
        ### räumliche Form des einströmenden Geschwindigkeitsprofils
        ### PARABEL- (später mal Poiseuille) oder KONSTANT
### Geschwindigkeitsverteilung am Einlass        
        #u_in_parabel=True
        if u_in_parabel:
            ## Parabelförmige Geschwindigkeit, vom zweiten bis vorletzten Randpunkt, damit die RB nicht mit den Wänden kollidiert
                ## How to Parabel:
                ## 1.Parabel in Nullstellenform: y = (x-x1)*(x-x2)
                ## 2.nach oben geöffnete Parabel mit Nullstelle bei x1=0 und x2=x0: y=-x*(x-x0)
                ## 3.skaliere Parabel, sodass der Scheitelpunkt immer bei ys=1.0 ist: y=-x*(x-x0)*(1/(x0/2)²)
                ## (4. optinal) skaliere Amplitude der Parabel mit 1.5, um dem Integral einer konstanten Einstromgeschwindigkeit zu entsprechen
            ny = f.shape[2] #Gitterpunktzahl in y-Richtung
            u1 = np.zeros((1,ny)) #x-Geschwindigkeiten der Randbedingung
            parabel_breite = ny-2 #lässt die Wand-Randbedingung aus, diese wird nicht belegt                
            y_werte = np.arange(0, parabel_breite) + 0.5 # die 0.5 shiftet die Parabel, sodass man Symmetrie erhält, sowohl bei geraden, als auch ungeraden Gitterpunktzahlen
            # Skalierungsfaktor 3/2=1.5 für die Parabelamplitude, falls man im Integral der Konstantgeschwindigkeit entsprechenn möchte.
            u1[:,1:-1] = - self.units.characteristic_velocity_lu * y_werte * (y_werte - (parabel_breite)) * 1/(parabel_breite/2)**2 # (!) es muss die charakteristische Geschwindigkeit in LU genutzt werden (!) -> der Unterschied PU/LU ist u.U. Größenordnungen und es kommt bei falscher Nutzung zu Schock/Überschall -> Crash
            # in 2D braucht u1 dann die Dimension 1 x ny (!)
            # u1 wird ux, u2 wird uy, beide stehen zusammen in u
            u2 = np.zeros_like(u1) #keine y-Geschwindigkeit
            u = np.stack([u1, u2], axis=0)
            u = self.lattice.convert_to_tensor(u)
            feq = self.lattice.equilibrium(rho, u) # Berechne Gleichgewichtsverteilung auf Einlassrand
            f[:,0,:]=feq[:, 0, :] # setze die FEQ mit parabelförmiger Geschwindigkeit nur auf den Einlass Rand
        else:
            ## konstante Geschwindigkeitswert (u_LU: 0.0289, u_PU: 1.0)        
            u = self.units.convert_velocity_to_lu(self.velocity) # ein Tensor: tensor([0.0289, 0.0000], device='cuda:0')
            feq = self.lattice.equilibrium(rho, u)
            feq = self.lattice.einsum("q,q->q", [feq, torch.ones_like(f)])
            #  feq = self.lattice.einsum("q,q->q", [feq, torch.ones_like(f)]) # "einsum" MÄCHTIG -> Matrix/Vektor verwurschteln. 
            # feq hat einen INdex q (hier velocities aus dem Stencil) -> kann ale Vektoroperationen vollführen, wenn man die Indizierung kennt und die an einsum() korrekt mitgibt
            # Die q-Dimension vom einen mit der q-Dimension vom anderen multipliziert, ergibt die neue q-Dimension des Ergebnisses
            # Vektorprodukt, Kreuzprodukt, Additione etc., sämtliche Vektor/Matrix/Tensor-Operationen lassen sich über Einsum abbilden
            f = torch.where(self.mask, feq, f)
        
        return f

# %%
### Parameter
#exmpl: Re1000,steps25000,ny1000 braucht 43min
    #re=10
    #n_steps=25000
    #ny=5 #nx=2*ny

# Inlet-Geschwindigkeitsverteilung: in EquilibriumBoundaryPU oben
# Wand-Randbindungen (BounceBack oder periodic) in boundary in Cylinder2D oben
# Störung in initial_solution in Cylinder2D oben

### Setup

lattice = lt.Lattice(lt.D2Q9, "cuda:0", dtype=torch.float64)
flow = Cylinder2D(
    (2*ny, ny), #shape der 2D-Box ist XxY: 2ny x ny
    reynolds_number=re, #50.0
    mach_number=0.05,
    lattice=lattice,
    domain_length_x=10.0 #10.1, # in PU
)

### Einlass-Randbedingung

# INLET mask wird bei "parabel" nicht verwendet (!) -> Maske ist dort direkt in der Belegung von f in der boundar-Klasse (s.o.) definiert
inmask = np.zeros(flow.grid[0].shape, dtype=bool)
inmask[0, 1:-1] = True # Ort der EquilibriumBoundaryPU RB: konret: kompletter linker Rand, exklusive Eckpunkten
boundary = EquilibriumBoundaryPU(
    inmask,
    flow.units.lattice, flow.units,
    flow.units.characteristic_velocity_pu * flow._unit_vector()
)
flow._boundary = boundary

### Definiere Obstacle (Zylinder)
if cylinder == True:
    x, y = flow.grid #gibt ein Meshgrid zurück: x-2D-Array, y-2D-Array
        # in der ursprünglichen Implementierung von grid mit "arange(n)" reicht das grid für n=10 z.B. von 0 bis 9... d.h. die Position 5 ist nicht in der Mitte (!)
        # in Cylnider2D (s.o.) ist das grid mit linspace erstellt und geht für n Punkte von 0 bis n inklusive 0 und n als Randpunkte
    #print("x grid ", x)
    #print("y grid ", y)

    # Zylinder - Kreisgleichung (x-x0)²+(y-y0)²<r² in PU
    condition = np.sqrt((x-2.5)**2+(y-2.5)**2) < 0.5 #die Kreisgleichung rechnet in PU, d.h. die Auflösung spielt hier keine Rolle(!)
    area=2*0.5
    flow.mask[np.where(condition)] = 1 #erstelle Obstacle Form (mask als Bool)
    boundary_mask = np.zeros_like(flow.mask)
    boundary_mask[np.where(condition)] = 1 #erstelle Obstacle Form (alleine, ohne etwaige andere BB-Boundaries)
    print("boundary_mask", boundary_mask)
        
#print("flow_obstacle_mask: ",flow.mask) #kontrolliere Symmetrie

forceOnBoundary = lt.ForceOnBoundary(boundary_mask, lattice)

tau = flow.units.relaxation_parameter_lu
sim = lt.Simulation(flow, lattice, lt.BGKCollision(lattice, tau), 
                    lt.StandardStreaming(lattice), forceOnBoundary)

### Reporter

# VTK Reporter -> Visualisierung
if vtk_out == True:
    VTKreport = lt.VTKReporter(lattice, flow, interval=vtk_interval, filename_base="/mnt/ScratchHDD1/Max_Scratch/cylinder_vtk/out")
    sim.reporters.append(VTKreport)

if drag_out == True:
    DragObservable = lt.DragCoefficient(lattice,flow,sim,area)
    Dragreport = lt.ObservableReporter(DragObservable, out=None)
    sim.reporters.append(Dragreport)
# Out:
# boundary_mask [[False False False False False]
#  [False False False False False]
#  [False False  True False False]
#  [False False False False False]
#  [False False False False False]
#  [False False False False False]
#  [False False False False False]
#  [False False False False False]
#  [False False False False False]
#  [False False False False False]]
# x: 10
# y: 5
# a: [2]
# b: [2]
# tensor([[[False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False]],
#
#         [[False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False,  True, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False]],
#
#         [[False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False,  True, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False]],
#
#         [[False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False,  True, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False]],
#
#         [[False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False,  True, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False]],
#
#         [[False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False,  True, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False]],
#
#         [[False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False,  True, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False]],
#
#         [[False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False,  True, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False]],
#
#         [[False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False,  True, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False],
#          [False, False, False, False, False]]], device='cuda:0')

# %%
# ### Simulation

# t_start=time.time()
# #sim.step(n_steps) #Simulation mit Schrittzahl n_steps
# print("PU-Time: ",flow.units.convert_time_to_pu(n_steps)," seconds")
# print("Re=",re)
# print("char_velocity_LU", flow.units.characteristic_velocity_lu)
# print("number of steps:",n_steps)
# print("runtime: ",time.time()-t_start, "seconds")

# %%
# sim.step(1)
# u = lattice.u(sim.f)
# print(" u nach step:",u)

# %%
diff_list = []
u_list = []

# %%
### Simulation mit u_diff

# Wähle Koordinaten des Geschwindigkeits-Messpunkts für die u_diff Analyse (relativ zum Gitter in LU)
nx, ny = flow.shape
x_test = int(nx/2)
y_test = int(ny/4)

t_start = time.time()
for i in range(n_steps):
    sim.step(1)
    #finde Asymmetrie der Geschwindigkeit in y-Richtung um Spiegelachse:
    #Differenz zwischen ux und ux an um y gespiegelt:
    u = lattice.u(sim.f)
    u_diff = torch.flip(u,[2])-u
    u_list.append(u[0,x_test,y_test].cpu())
    diff_list.append(u_diff[0,x_test,y_test].cpu())
t_end = time.time()-t_start
print("PU-Time: ",flow.units.convert_time_to_pu(n_steps)," seconds")
print("number of steps:",n_steps)
print("runtime: ",time.time()-t_start, "seconds")
# Out:
# force tensor([0., 0.], device='cuda:0', dtype=torch.float64)
# Fw tensor(0., device='cuda:0', dtype=torch.float64)
# force tensor([0., 0.], device='cuda:0', dtype=torch.float64)
# Fw tensor(0., device='cuda:0', dtype=torch.float64)
# force tensor([0., 0.], device='cuda:0', dtype=torch.float64)
# Fw tensor(0., device='cuda:0', dtype=torch.float64)
# force tensor([0., 0.], device='cuda:0', dtype=torch.float64)
# Fw tensor(0., device='cuda:0', dtype=torch.float64)
# force tensor([-0.0082,  0.0000], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0082, device='cuda:0', dtype=torch.float64)
# force tensor([-1.2944e-02,  5.5511e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0129, device='cuda:0', dtype=torch.float64)
# force tensor([-1.0734e-02,  2.7756e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0107, device='cuda:0', dtype=torch.float64)
# force tensor([-8.6260e-03,  9.0206e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0086, device='cuda:0', dtype=torch.float64)
# force tensor([-5.8473e-03,  2.1511e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0058, device='cuda:0', dtype=torch.float64)
# force tensor([-5.5751e-03, -6.9389e-18], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0056, device='cuda:0', dtype=torch.float64)
# force tensor([-3.6809e-03, -3.3307e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0037, device='cuda:0', dtype=torch.float64)
# force tensor([-3.1725e-03, -1.9429e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0032, device='cuda:0', dtype=torch.float64)
# force tensor([-3.1184e-03, -6.2450e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0031, device='cuda:0', dtype=torch.float64)
# force tensor([-3.1747e-03,  9.0206e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0032, device='cuda:0', dtype=torch.float64)
# force tensor([-3.9359e-03, -6.2450e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0039, device='cuda:0', dtype=torch.float64)
# force tensor([-1.8699e-03, -2.7062e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0019, device='cuda:0', dtype=torch.float64)
# force tensor([2.2512e-05, 2.7062e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(2.2512e-05, device='cuda:0', dtype=torch.float64)
# force tensor([3.2956e-04, 4.8572e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(0.0003, device='cuda:0', dtype=torch.float64)
# force tensor([-5.7197e-04,  2.0123e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-2.1965e-03, -1.1102e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0022, device='cuda:0', dtype=torch.float64)
# force tensor([-1.4306e-03, -4.1633e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0014, device='cuda:0', dtype=torch.float64)
# force tensor([-6.5439e-04, -1.4572e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-8.4420e-04, -4.2327e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-1.6495e-04, -3.4694e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0002, device='cuda:0', dtype=torch.float64)
# force tensor([-7.3463e-04,  3.3307e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-1.9740e-03,  7.5634e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0020, device='cuda:0', dtype=torch.float64)
# force tensor([-2.3052e-03,  2.0817e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0023, device='cuda:0', dtype=torch.float64)
# force tensor([-2.6567e-03,  1.5266e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0027, device='cuda:0', dtype=torch.float64)
# force tensor([-3.7176e-03,  3.3307e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0037, device='cuda:0', dtype=torch.float64)
# force tensor([-5.0785e-03, -3.3307e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0051, device='cuda:0', dtype=torch.float64)
# force tensor([-5.0954e-03, -6.3144e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0051, device='cuda:0', dtype=torch.float64)
# force tensor([-4.7086e-03, -4.6491e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0047, device='cuda:0', dtype=torch.float64)
# force tensor([-5.1888e-03, -2.9143e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0052, device='cuda:0', dtype=torch.float64)
# force tensor([-4.6878e-03, -6.2450e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0047, device='cuda:0', dtype=torch.float64)
# force tensor([-3.3682e-03, -1.5266e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0034, device='cuda:0', dtype=torch.float64)
# force tensor([-2.4278e-03,  1.7347e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0024, device='cuda:0', dtype=torch.float64)
# force tensor([-1.7703e-03,  4.9960e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0018, device='cuda:0', dtype=torch.float64)
# force tensor([-1.8919e-03,  2.9837e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0019, device='cuda:0', dtype=torch.float64)
# force tensor([-2.1807e-03, -1.7347e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0022, device='cuda:0', dtype=torch.float64)
# force tensor([-1.6855e-03, -1.3184e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0017, device='cuda:0', dtype=torch.float64)
# force tensor([-1.2511e-03,  4.0246e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0013, device='cuda:0', dtype=torch.float64)
# force tensor([-1.2771e-03,  1.6653e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0013, device='cuda:0', dtype=torch.float64)
# force tensor([-1.1762e-03, -2.7756e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0012, device='cuda:0', dtype=torch.float64)
# force tensor([-9.9893e-04, -9.7145e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0010, device='cuda:0', dtype=torch.float64)
# force tensor([-1.0065e-03, -3.4001e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0010, device='cuda:0', dtype=torch.float64)
# force tensor([-8.2072e-04, -3.3307e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-4.4165e-04,  2.3592e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0004, device='cuda:0', dtype=torch.float64)
# force tensor([-3.2436e-04,  2.7756e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0003, device='cuda:0', dtype=torch.float64)
# force tensor([-3.6949e-04,  3.0531e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0004, device='cuda:0', dtype=torch.float64)
# force tensor([-4.4461e-04,  1.1102e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0004, device='cuda:0', dtype=torch.float64)
# force tensor([-5.3853e-04, -1.1102e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0005, device='cuda:0', dtype=torch.float64)
# force tensor([-5.0354e-04,  2.5674e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0005, device='cuda:0', dtype=torch.float64)
# force tensor([-4.9937e-04,  4.3021e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0005, device='cuda:0', dtype=torch.float64)
# force tensor([-4.8844e-04,  1.0408e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0005, device='cuda:0', dtype=torch.float64)
# force tensor([-4.4411e-04, -2.5674e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0004, device='cuda:0', dtype=torch.float64)
# force tensor([-3.0285e-04, -2.9837e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0003, device='cuda:0', dtype=torch.float64)
# force tensor([ 3.0673e-04, -4.8572e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(0.0003, device='cuda:0', dtype=torch.float64)
# force tensor([ 8.2977e-04, -2.2204e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([8.2310e-04, 1.5266e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([7.4068e-04, 2.0817e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([4.5024e-04, 3.3307e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(0.0005, device='cuda:0', dtype=torch.float64)
# force tensor([2.1878e-04, 2.9143e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(0.0002, device='cuda:0', dtype=torch.float64)
# force tensor([ 3.0339e-04, -2.0817e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(0.0003, device='cuda:0', dtype=torch.float64)
# force tensor([ 9.3318e-06, -5.5511e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(9.3318e-06, device='cuda:0', dtype=torch.float64)
# force tensor([-5.0894e-04,  6.9389e-18], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0005, device='cuda:0', dtype=torch.float64)
# force tensor([-6.7499e-04, -8.3267e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-4.1459e-04, -9.0206e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0004, device='cuda:0', dtype=torch.float64)
# force tensor([ 7.9052e-05, -9.7145e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(7.9052e-05, device='cuda:0', dtype=torch.float64)
# force tensor([0.0002, 0.0000], device='cuda:0', dtype=torch.float64)
# Fw tensor(0.0002, device='cuda:0', dtype=torch.float64)
# force tensor([-7.9614e-05,  9.0206e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-7.9614e-05, device='cuda:0', dtype=torch.float64)
# force tensor([-1.5056e-04,  4.9266e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0002, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9967e-05,  2.7756e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-8.9967e-05, device='cuda:0', dtype=torch.float64)
# force tensor([ 6.8056e-05, -2.1511e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(6.8056e-05, device='cuda:0', dtype=torch.float64)
# force tensor([-3.3255e-06,  2.0123e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-3.3255e-06, device='cuda:0', dtype=torch.float64)
# force tensor([-4.0936e-04, -6.2450e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0004, device='cuda:0', dtype=torch.float64)
# force tensor([-6.2714e-04, -3.8164e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-5.9432e-04,  8.3267e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-5.1792e-04, -1.1102e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0005, device='cuda:0', dtype=torch.float64)
# force tensor([-5.5404e-04, -8.3267e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-7.4720e-04,  5.0654e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-8.5251e-04,  4.5797e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-6.9861e-04, -1.4572e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-4.4134e-04, -4.0246e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0004, device='cuda:0', dtype=torch.float64)
# force tensor([-3.8224e-04, -1.8735e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0004, device='cuda:0', dtype=torch.float64)
# force tensor([-4.7016e-04,  2.0817e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0005, device='cuda:0', dtype=torch.float64)
# force tensor([-4.5774e-04,  2.3592e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0005, device='cuda:0', dtype=torch.float64)
# force tensor([-4.6057e-04,  2.3592e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0005, device='cuda:0', dtype=torch.float64)
# force tensor([-4.9146e-04,  1.9429e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0005, device='cuda:0', dtype=torch.float64)
# force tensor([-5.4857e-04,  1.8041e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0005, device='cuda:0', dtype=torch.float64)
# force tensor([-6.9954e-04, -2.9143e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-7.6307e-04, -4.2327e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-7.0651e-04,  7.6328e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-6.3628e-04,  1.9429e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-5.8454e-04,  6.2450e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-5.9567e-04, -3.4694e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-5.8729e-04, -2.0123e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-5.9820e-04,  6.9389e-18], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-6.1617e-04, -6.9389e-18], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-5.6187e-04,  5.3429e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-5.3573e-04,  1.3878e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0005, device='cuda:0', dtype=torch.float64)
# force tensor([-4.9866e-04, -2.6368e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0005, device='cuda:0', dtype=torch.float64)
# force tensor([-4.3413e-04, -8.3267e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0004, device='cuda:0', dtype=torch.float64)
# force tensor([-4.5340e-04, -4.0246e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0005, device='cuda:0', dtype=torch.float64)
# force tensor([-4.5322e-04, -3.4694e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0005, device='cuda:0', dtype=torch.float64)
# force tensor([-4.7192e-04,  7.6328e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0005, device='cuda:0', dtype=torch.float64)
# force tensor([-5.8370e-04, -1.5959e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-6.6552e-04,  6.2450e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-6.6982e-04,  4.5797e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-6.3749e-04, -1.5959e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-5.6485e-04, -1.5959e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-4.7213e-04, -5.5511e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0005, device='cuda:0', dtype=torch.float64)
# force tensor([-4.2629e-04, -1.8041e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0004, device='cuda:0', dtype=torch.float64)
# force tensor([-4.3239e-04, -2.9143e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0004, device='cuda:0', dtype=torch.float64)
# force tensor([-4.1869e-04, -2.3592e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0004, device='cuda:0', dtype=torch.float64)
# force tensor([-4.7644e-04, -1.9429e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0005, device='cuda:0', dtype=torch.float64)
# force tensor([-5.9746e-04, -1.2490e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-6.3910e-04,  3.6082e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-6.3287e-04,  6.8695e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-6.1396e-04,  1.3184e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-5.5399e-04, -2.7062e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-5.2313e-04, -2.4286e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0005, device='cuda:0', dtype=torch.float64)
# force tensor([-5.2563e-04, -1.1796e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0005, device='cuda:0', dtype=torch.float64)
# force tensor([-5.2480e-04, -1.3878e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0005, device='cuda:0', dtype=torch.float64)
# force tensor([-5.3602e-04,  1.3878e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0005, device='cuda:0', dtype=torch.float64)
# force tensor([-6.0744e-04, -2.4286e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-6.7002e-04,  1.7347e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-6.4511e-04,  7.3552e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-6.1198e-04, -2.7756e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-5.9563e-04, -3.1919e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-5.5534e-04,  4.1633e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-5.7607e-04, -1.4572e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-6.1707e-04, -5.4817e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-6.1184e-04,  1.0408e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-6.4085e-04, -1.3878e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-6.9981e-04, -4.8572e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-6.9068e-04,  7.6328e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-6.4326e-04, -6.2450e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-6.1635e-04, -9.7145e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-6.0016e-04,  1.1796e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-6.0316e-04,  3.8164e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-6.6154e-04, -2.0817e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-7.0073e-04, -4.3715e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-6.9422e-04,  1.4572e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-7.0622e-04, -2.2898e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-7.0919e-04, -9.0206e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-6.6142e-04,  3.3307e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-6.2510e-04,  1.3878e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-6.1640e-04,  2.2898e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-6.2122e-04,  1.3184e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-6.6170e-04, -3.2613e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-7.3240e-04, -2.0817e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-7.5989e-04, -9.0206e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-7.4290e-04,  3.6082e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-7.2760e-04,  3.4694e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-6.9347e-04, -1.3184e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-6.4397e-04, -3.1225e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-6.3773e-04, -1.9429e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0006, device='cuda:0', dtype=torch.float64)
# force tensor([-6.5133e-04, -1.1102e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-6.7197e-04, -1.3878e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-7.2593e-04, -4.1633e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-0.0008,  0.0000], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-7.7584e-04,  2.0817e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-7.4445e-04,  6.9389e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-7.1095e-04,  1.3878e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-6.7558e-04,  4.6491e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-6.5859e-04, -6.9389e-18], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-6.8408e-04, -2.3592e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-7.1683e-04, -2.2204e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-7.4386e-04, -2.7062e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-7.8259e-04, -8.3267e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-7.9897e-04,  6.9389e-18], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-7.6774e-04,  1.3878e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-7.2831e-04,  4.3021e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-7.0082e-04,  2.8449e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-6.8507e-04, -3.4694e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-7.0252e-04, -4.8572e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-7.4831e-04,  5.5511e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-7.7991e-04, -1.4572e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-7.9594e-04,  6.2450e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.0866e-04, -9.7145e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-7.9008e-04, -2.5674e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-7.4917e-04,  1.2490e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-7.2688e-04, -2.3592e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-7.2123e-04, -2.9837e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-7.3087e-04,  5.5511e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-7.7072e-04,  3.0531e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.1041e-04, -2.7062e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.2122e-04,  1.5959e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.1627e-04,  2.1511e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.0023e-04, -2.8449e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-7.6436e-04, -2.9837e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-7.4143e-04,  2.7756e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-7.4867e-04,  1.4572e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0007, device='cuda:0', dtype=torch.float64)
# force tensor([-7.6625e-04, -3.0531e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-7.9438e-04, -1.1102e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.3443e-04,  1.3184e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.4797e-04,  9.7145e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.3460e-04,  5.0654e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.1248e-04,  4.5103e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-7.8050e-04, -4.7184e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-7.5357e-04, -1.5266e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-7.6371e-04, -4.1633e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-7.9171e-04, -2.9837e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.2027e-04,  4.3715e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.5075e-04,  3.4694e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.6782e-04, -5.3429e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.5143e-04,  6.9389e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.2660e-04,  1.3878e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-7.9889e-04, -2.0123e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-7.7396e-04,  3.4694e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-7.7687e-04,  4.4409e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.1149e-04, -5.0654e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.4196e-04, -5.6899e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.6764e-04, -1.5959e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8078e-04, -4.8572e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.6729e-04,  6.9389e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.3596e-04,  4.0246e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.1426e-04,  2.9143e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-7.9549e-04,  4.1633e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-7.9623e-04,  1.1102e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.2606e-04,  9.7145e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.6307e-04, -2.0817e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8112e-04,  9.7145e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9167e-04, -2.0123e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.7941e-04, -5.0654e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.4873e-04, -1.4572e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.2305e-04, -1.2490e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.1574e-04, -1.9429e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.1647e-04,  3.5388e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.4293e-04,  5.3429e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.7851e-04,  4.9266e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9852e-04,  2.2204e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9724e-04, -2.1511e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8822e-04, -5.8981e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.5961e-04, -4.7184e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.3419e-04, -1.1796e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.2755e-04,  1.5266e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.3886e-04,  2.5674e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.5809e-04,  3.2613e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9254e-04,  4.5797e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.1231e-04,  2.6368e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.0897e-04, -3.2613e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9040e-04,  4.8572e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.6988e-04, -9.0206e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.4405e-04, -9.7145e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.3902e-04, -7.9103e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.5316e-04,  1.3878e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.7774e-04,  9.7145e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.0132e-04,  7.5634e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.2330e-04,  1.2212e-15], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.1860e-04,  4.4409e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9766e-04, -7.0777e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.7301e-04, -7.3552e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.5669e-04, -3.1919e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.4815e-04, -1.5266e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0008, device='cuda:0', dtype=torch.float64)
# force tensor([-8.6524e-04, -6.9389e-18], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9125e-04,  3.3307e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.1532e-04, -1.3878e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.2697e-04, -1.2490e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.2708e-04,  4.7184e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.0344e-04,  2.9837e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.7878e-04,  3.3307e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.6274e-04,  1.2490e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.6215e-04, -5.9674e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.7293e-04, -3.3307e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.0213e-04, -1.8041e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.2485e-04, -5.5511e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.3472e-04,  2.4980e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.2780e-04,  4.6491e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.1079e-04,  1.3878e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8261e-04, -5.9674e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.6942e-04, -2.4286e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.7081e-04,  2.5674e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8602e-04, -8.3267e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.0719e-04,  2.0817e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.3294e-04,  2.0817e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.3901e-04, -3.6776e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.3080e-04,  1.3878e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.1101e-04,  4.1633e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8995e-04, -1.5266e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.7270e-04, -3.1919e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.7888e-04,  8.3267e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9491e-04, -3.4694e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.1670e-04, -4.0246e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.3472e-04,  6.2450e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.4402e-04,  3.5388e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.3069e-04,  1.2490e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.1217e-04,  1.5266e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9163e-04, -1.2490e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8013e-04, -5.5511e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8199e-04,  6.2450e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.0325e-04,  3.6082e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.2265e-04,  2.8449e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.3923e-04, -4.0246e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.4312e-04, -6.6613e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.3320e-04, -2.2898e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.0974e-04,  1.1102e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9373e-04, -3.6776e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8333e-04, -4.0939e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8852e-04,  6.7307e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.0574e-04,  6.9389e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.2917e-04, -2.7756e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.4018e-04,  9.0206e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.4358e-04, -6.9389e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.3094e-04, -5.8981e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.1083e-04, -9.7145e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9136e-04, -1.2490e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8738e-04, -2.6368e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9149e-04, -3.4694e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.1021e-04, -6.9389e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.3001e-04,  4.3021e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.4307e-04,  4.9960e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.3989e-04,  1.2490e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.2978e-04, -2.7756e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.0828e-04, -4.6491e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9223e-04, -3.0531e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8642e-04,  2.0817e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9629e-04,  6.2450e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.1082e-04, -6.2450e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.3183e-04, -3.4694e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.4119e-04, -1.1796e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.3893e-04,  2.4286e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.2372e-04,  3.4694e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.0758e-04,  3.5388e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8980e-04, -3.3307e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8780e-04, -5.5511e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9615e-04, -6.2450e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.1411e-04,  2.2204e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.2891e-04,  5.4817e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.4045e-04, -8.3267e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.3407e-04, -2.3592e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.2052e-04,  4.1633e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.0164e-04, -2.8449e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9031e-04, -1.3878e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8526e-04,  3.4694e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9776e-04,  6.9389e-18], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.1286e-04,  1.5266e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.2911e-04, -5.5511e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.3422e-04, -2.1511e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.3151e-04,  1.9429e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.1363e-04,  3.4694e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9843e-04, -4.0246e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8566e-04, -2.0123e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8646e-04,  4.5797e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9435e-04,  4.7184e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.1357e-04,  3.4694e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.2499e-04,  2.9143e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.3126e-04,  1.8041e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.2316e-04, -2.7756e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.1044e-04, -1.9429e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9097e-04, -2.0817e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8377e-04, -2.0817e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8266e-04, -1.1796e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9501e-04, -5.5511e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.0830e-04,  2.8449e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.2378e-04,  2.7756e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.2385e-04,  4.1633e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.1830e-04,  2.4980e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.0155e-04,  1.5959e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8828e-04, -4.0939e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.7671e-04, -2.4980e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8203e-04, -1.6653e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9064e-04,  1.5959e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.0719e-04,  4.7184e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.1607e-04, -6.9389e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.2057e-04, -3.8164e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.0852e-04, -1.4572e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9653e-04, -7.6328e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8009e-04,  2.3592e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.7494e-04,  1.1102e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.7529e-04, -2.9143e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9016e-04,  9.7145e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.0081e-04,  3.5388e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.1265e-04, -2.0817e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.1079e-04, -1.4572e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.0394e-04,  5.5511e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8597e-04, -1.1796e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.7627e-04, -3.6082e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.6772e-04, -6.2450e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.7391e-04,  1.8041e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8300e-04,  1.3878e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9916e-04,  2.2204e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.0360e-04,  1.6653e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.0558e-04, -7.6328e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9322e-04, -2.3592e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8124e-04, -3.3307e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.6635e-04, -5.7593e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.6542e-04, -8.3267e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.6694e-04,  2.6368e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8102e-04,  4.8572e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9078e-04,  5.6205e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-9.0002e-04,  1.5266e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9442e-04,  1.3878e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8749e-04, -6.3144e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.7079e-04, -5.0654e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.6234e-04,  2.6368e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.5673e-04, -9.7145e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.6535e-04, -6.9389e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.7320e-04,  2.7756e-17], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.8745e-04, -3.3307e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# force tensor([-8.9011e-04,  2.4286e-16], device='cuda:0', dtype=torch.float64)
# Fw tensor(-0.0009, device='cuda:0', dtype=torch.float64)
# PU-Time:  11.547005383792516  seconds
# number of steps: 400
# runtime:  0.7781956195831299 seconds

# %%
### plot u_diff - Symmetrieuntersuchung der Geschwindigkeit

fig, axs = plt.subplots(1, 2, figsize=(10, 2.7), layout='constrained')
axs[0].plot(u_list)
axs[0].set_title("u @ x,y = "+str(x_test)+","+str(y_test))
axs[1].plot(diff_list)
axs[1].set_title("u_diff @ x,y = "+str(x_test)+","+str(y_test))
# Out:
# Text(0.5, 1.0, 'u_diff @ x,y = 5,1')

# %%
### print sim parms

print("### sim parms ###")
print("Re = ", re)
print("n_steps = ", n_steps)
print("nx x ny = ", 2*ny, " x ", ny)
print("u_init = ", u_init)
print("u_in_parabel = ", u_in_parabel)
print("bb_wall = ", bb_wall)
print("cylinder = ", cylinder)
print("vtk_out = ", vtk_out)
# Out:
# ### sim parms ###
# Re =  100
# n_steps =  400
# nx x ny =  10  x  5
# u_init =  1
# u_in_parabel =  True
# bb_wall =  False
# cylinder =  True
# vtk_out =  False

# %%
### plot Drag coefficient

drag_coefficient = np.array(Dragreport.out)
print(drag_coefficient)
plt.figure
plt.plot(drag_coefficient[:,0],drag_coefficient[:,1],'o')
# Out:
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 1.00000000e+00  2.88675135e-02  0.00000000e+00]
#  [ 2.00000000e+00  5.77350269e-02  0.00000000e+00]
#  ...
#  [ 3.98000000e+02  1.14892704e+01 -2.09567690e+00]
#  [ 3.99000000e+02  1.15181379e+01 -2.12986935e+00]
#  [ 4.00000000e+02  1.15470054e+01 -2.13626994e+00]]

# %%
print(u.max())
# Out:
# tensor(0.0289, device='cuda:0', dtype=torch.float64)

# %%
print(u.min())
# Out:
# tensor(-0.0150, device='cuda:0', dtype=torch.float64)
